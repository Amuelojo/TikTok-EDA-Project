# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
print(df.tail())
# Out:
#            # claim_status    video_id  video_duration_sec  \
# 19377  19378          NaN  7578226840                  21
# 19378  19379          NaN  6079236179                  53
# 19379  19380          NaN  2565539685                  10
# 19380  19381          NaN  2969178540                  24
# 19381  19382          NaN  8132759688                  13
#
#       video_transcription_text verified_status author_ban_status  \
# 19377                      NaN    not verified            active
# 19378                      NaN    not verified            active
# 19379                      NaN        verified      under review
# 19380                      NaN    not verified            active
# 19381                      NaN    not verified            active
#
#        video_view_count  video_like_count  video_share_count  \
# 19377               NaN               NaN                NaN
# 19378               NaN               NaN                NaN
# ...

# %%
print(df.describe())
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB
# None

# %%
print(df.columns)
# Out:
# Index(['#', 'claim_status', 'video_id', 'video_duration_sec',
#        'video_transcription_text', 'verified_status', 'author_ban_status',
#        'video_view_count', 'video_like_count', 'video_share_count',
#        'video_download_count', 'video_comment_count'],
#       dtype='object')

# %%
# Check for missing values in each column
missing_data = df.isnull().sum()

# Display the columns with missing values
print("Missing data in each column:")
print(missing_data)
# Out:
# Missing data in each column:
# #                             0
# claim_status                298
# video_id                      0
# video_duration_sec            0
# video_transcription_text    298
# verified_status               0
# author_ban_status             0
# video_view_count            298
# video_like_count            298
# video_share_count           298
# video_download_count        298
# video_comment_count         298
# dtype: int64

# %%
# Optionally, you can also check the percentage of missing data
missing_data_percentage = (df.isnull().sum() / len(df)) * 100

# Display the percentage of missing data in each column
print("\nPercentage of missing data in each column:")
print(missing_data_percentage)
# Out:
# Percentage of missing data in each column:
# #                           0.000000
# claim_status                1.537509
# video_id                    0.000000
# video_duration_sec          0.000000
# video_transcription_text    1.537509
# verified_status             0.000000
# author_ban_status           0.000000
# video_view_count            1.537509
# video_like_count            1.537509
# video_share_count           1.537509
# video_download_count        1.537509
# video_comment_count         1.537509
# dtype: float64

# %%
# Check the data types of each column
print(df.dtypes)
# Out:
# #                             int64
# claim_status                 object
# video_id                      int64
# video_duration_sec            int64
# video_transcription_text     object
# verified_status              object
# author_ban_status            object
# video_view_count            float64
# video_like_count            float64
# video_share_count           float64
# video_download_count        float64
# video_comment_count         float64
# dtype: object

# %%
# Step 1: Count missing values
missing_values = df.isnull().sum()

# Step 2: Calculate total number of rows
total_rows = df.shape[0]

# Step 3: Calculate percentage of missing values for each column
percentage_missing = (missing_values / total_rows) * 100

# Print or display the percentage of missing values
print("Percentage of missing values in each column:")
print(percentage_missing)
# Out:
# Percentage of missing values in each column:
# #                           0.000000
# claim_status                1.537509
# video_id                    0.000000
# video_duration_sec          0.000000
# video_transcription_text    1.537509
# verified_status             0.000000
# author_ban_status           0.000000
# video_view_count            1.537509
# video_like_count            1.537509
# video_share_count           1.537509
# video_download_count        1.537509
# video_comment_count         1.537509
# dtype: float64

# %%
# Example DataFrame (replace with your actual DataFrame)
data = {
    'column1': [1, 2, None, 4, 5],
    'column2': ['A', 'B', 'C', None, 'E']
}

df = pd.DataFrame(data)

# Replace 'column1' with your actual column name
column_name = 'column1'

# Step 1: Count the occurrences of NaN (missing values)
missing_count = df[column_name].isnull().sum()

# Step 2: Calculate the total number of entries (excluding NaN)
total_entries = df[column_name].count()

# Step 3: Calculate the percentage of missing values
if total_entries > 0:
    percentage_missing = (missing_count / total_entries) * 100
else:
    percentage_missing = 0.0  # To handle case where total_entries is zero

# Print or display the percentage of missing values
print(f"Percentage of missing values in column '{column_name}': {percentage_missing:.2f}%")
# Out:
# Percentage of missing values in column 'column1': 25.00%

# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Define a function to calculate the percentage of outliers in a variable
def calculate_outliers_percentage(data, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    outliers_count = outliers.shape[0]
    total_count = df.shape[0]

    return (outliers_count / total_count) * 100

# Relevant variables
relevant_variables = [
    'video_view_count',
    'video_like_count',
    'video_share_count',
    'video_download_count',
    'video_comment_count'
]

# Calculate and print the percentage of outliers for each relevant variable
outliers_percentage = {}
for variable in relevant_variables:
    percentage = calculate_outliers_percentage(df, variable)
    outliers_percentage[variable] = percentage
    print(f"Percentage of outliers in {variable}: {percentage:.2f}%")

# Calculate the overall percentage of outliers across all relevant variables
overall_outliers = df[
    (df['video_view_count'] < df['video_view_count'].quantile(0.25) - 1.5 * (df['video_view_count'].quantile(0.75) - df['video_view_count'].quantile(0.25))) |
    (df['video_view_count'] > df['video_view_count'].quantile(0.75) + 1.5 * (df['video_view_count'].quantile(0.75) - df['video_view_count'].quantile(0.25))) |
    (df['video_like_count'] < df['video_like_count'].quantile(0.25) - 1.5 * (df['video_like_count'].quantile(0.75) - df['video_like_count'].quantile(0.25))) |
    (df['video_like_count'] > df['video_like_count'].quantile(0.75) + 1.5 * (df['video_like_count'].quantile(0.75) - df['video_like_count'].quantile(0.25))) |
    (df['video_share_count'] < df['video_share_count'].quantile(0.25) - 1.5 * (df['video_share_count'].quantile(0.75) - df['video_share_count'].quantile(0.25))) |
    (df['video_share_count'] > df['video_share_count'].quantile(0.75) + 1.5 * (df['video_share_count'].quantile(0.75) - df['video_share_count'].quantile(0.25))) |
    (df['video_download_count'] < df['video_download_count'].quantile(0.25) - 1.5 * (df['video_download_count'].quantile(0.75) - df['video_download_count'].quantile(0.25))) |
    (df['video_download_count'] > df['video_download_count'].quantile(0.75) + 1.5 * (df['video_download_count'].quantile(0.75) - df['video_download_count'].quantile(0.25))) |
    (df['video_comment_count'] < df['video_comment_count'].quantile(0.25) - 1.5 * (df['video_comment_count'].quantile(0.75) - df['video_comment_count'].quantile(0.25))) |
    (df['video_comment_count'] > df['video_comment_count'].quantile(0.75) + 1.5 * (df['video_comment_count'].quantile(0.75) - df['video_comment_count'].quantile(0.25)))
]

overall_outliers_percentage = (overall_outliers.shape[0] / df.shape[0]) * 100
print(f"Overall percentage of outliers across all relevant variables: {overall_outliers_percentage:.2f}%")
# Out:
# Percentage of outliers in video_view_count: 0.00%
# Percentage of outliers in video_like_count: 8.91%
# Percentage of outliers in video_share_count: 12.94%
# Percentage of outliers in video_download_count: 12.64%
# Percentage of outliers in video_comment_count: 14.39%
# Overall percentage of outliers across all relevant variables: 21.84%

# %%
# Get the size of the data

print(df.size)
# Out:
# 232584

# %%
# Get the shape of the data
### YOUR CODE HERE ###
print(df.shape)
# Out:
# (19382, 12)

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
### YOUR CODE HERE ###


# Plot box plot for video_duration_sec
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['video_duration_sec'])
plt.title('Box Plot of Video Duration (Seconds)')
plt.ylabel('Video Duration (Seconds)')
plt.show()

# %%
# Plot histogram for video_duration_sec
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Plot histogram for video_duration_sec
plt.figure(figsize=(10, 6))
sns.histplot(df['video_duration_sec'], bins=30, kde=True)
plt.title('Distribution of Video Duration (Seconds)')
plt.xlabel('Video Duration (Seconds)')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a boxplot to visualize distribution of `video_view_count`
### YOUR CODE HERE ###
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Load the dataset
df = pd.read_csv(file_path)

# Plot box plot for video_view_count
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['video_view_count'])
plt.title('Box Plot of Video View Count')
plt.ylabel('Video View Count')
plt.show()

# %%
#Create a histogram of the values in the video_view_count column to further explore the distribution of this variable.
# Create a histogram
### YOUR CODE HERE ###
# Create a boxplot to visualize distribution of `video_view_count`
### YOUR CODE HERE ###
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Plot histogram for video_view_count
plt.figure(figsize=(10, 6))
sns.histplot(df['video_view_count'], bins=30, kde=True)
plt.title('Distribution of Video View Count')
plt.xlabel('Video View Count')
plt.ylabel('Frequency')
plt.show()

# %%
# # Create a boxplot to visualize distribution of `video_like_count`
### YOUR CODE HERE ###
### YOUR CODE HERE ###
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Create a box plot for video_like_count
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['video_like_count'])
plt.title('Box Plot of Video Like Count')
plt.xlabel('Video Like Count')
plt.show()

# %%
#Create a histogram of the values in the video_like_count column to further explore the distribution of this variable.

# Create a histogram
### YOUR CODE HERE ###
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Create a histogram for video_like_count
plt.figure(figsize=(10, 6))
sns.histplot(df['video_like_count'], kde=True, bins=30)
plt.title('Distribution of Video Like Count')
plt.xlabel('Video Like Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
### YOUR CODE HERE ###

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'


# Create a boxplot for video_comment_count
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['video_comment_count'])
plt.title('Distribution of Video Comment Count')
plt.xlabel('Video Comment Count')
plt.show()

# %%
# Create a histogram
### YOUR CODE HERE ###
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'


# Create a histogram for video_comment_count
plt.figure(figsize=(10, 6))
sns.histplot(df['video_comment_count'], bins=30, kde=True)
plt.title('Distribution of Video Comment Count')
plt.xlabel('Video Comment Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a boxplot to visualize distribution of `video_share_count`
### YOUR CODE HERE ###

import matplotlib.pyplot as plt
import seaborn as sns

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Assuming 'data' is your DataFrame and it has been loaded correctly
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['video_share_count'])
plt.title('Distribution of Video Share Count')
plt.xlabel('Video Share Count')
plt.show()

# %%
#Create a histogram of the values in the video_share_count column to further explore the distribution of this variable.
# Create a histogram
### YOUR CODE HERE ###

import matplotlib.pyplot as plt
import seaborn as sns


# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'
# Assuming 'data' is your DataFrame and it has been loaded correctly
plt.figure(figsize=(10, 6))
sns.histplot(df['video_share_count'], bins=30, kde=True)
plt.title('Distribution of Video Share Count')
plt.xlabel('Video Share Count')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a boxplot to visualize distribution of `video_download_count`
### YOUR CODE HERE ###
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Assuming 'data' is your DataFrame and it has been loaded correctly
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['video_download_count'])
plt.title('Distribution of Video Download Count')
plt.xlabel('Video Download Count')
plt.show()

# %%
# Create a histogram
### YOUR CODE HERE ### 
#Create a histogram of the values in the video_download_count column to further explore the distribution of this variable.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Correct path to the CSV file
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Assuming 'data' is your DataFrame and it has been loaded correctly
plt.figure(figsize=(10, 6))
sns.histplot(df['video_download_count'], bins=30, kde=True)
plt.title('Distribution of Video Download Count')
plt.xlabel('Video Download Count')
plt.ylabel('Frequency')
plt.show()

# %%
#Now, create a histogram with four bars: one for each combination of claim status and verification status.

# Create a histogram
### YOUR CODE HERE ###

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Group by 'claim_status' and 'verified_status' and count occurrences
grouped = df.groupby(['claim_status', 'verified_status']).size().reset_index(name='count')

# Plotting the histogram with four bars
plt.figure(figsize=(10, 6))
sns.barplot(x='claim_status', y='count', hue='verified_status', data=grouped)
plt.title('Histogram of Claim Status and Verification Status')
plt.xlabel('Claim Status')
plt.ylabel('Count')
plt.legend(title='Verification Status')
plt.show()

# %%
##### **Claim status by author ban status**

#The previous course used a `groupby()` statement to examine the count of each claim status for each author ban status. Now, use a histogram to communicate the same information.
# Create a histogram
### YOUR CODE HERE ###
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Group by 'claim_status' and 'author_ban_status' and count occurrences
grouped = df.groupby(['claim_status', 'author_ban_status']).size().reset_index(name='count')

# Plotting the histogram with bars
plt.figure(figsize=(12, 6))
sns.barplot(x='claim_status', y='count', hue='author_ban_status', data=grouped)
plt.title('Histogram of Claim Status by Author Ban Status')
plt.xlabel('Claim Status')
plt.ylabel('Count')
plt.legend(title='Author Ban Status')
plt.show()

# %%
#Create a bar plot with three bars: one for each author ban status. The height of each bar should correspond with the median number of views for all videos with that author ban status.
# Create a bar plot
### YOUR CODE HERE ###
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Calculate median number of views for each author_ban_status
median_views = df.groupby('author_ban_status')['video_view_count'].median().reset_index()

# Plotting the bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x='author_ban_status', y='video_view_count', data=median_views)
plt.title('Median Number of Views by Author Ban Status')
plt.xlabel('Author Ban Status')
plt.ylabel('Median Number of Views')
plt.show()

# %%
# Calculate the median view count for claim status.
### YOUR CODE HERE ###

import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Filter data for videos with claim status
claim_videos = df[df['claim_status'] == 'claim']

# Calculate median view count for claim videos
median_view_count_claim = claim_videos['video_view_count'].median()

print(f"Median view count for claim videos: {median_view_count_claim}")
# Out:
# Median view count for claim videos: 501555.0

# %%
# Create a pie graph
### YOUR CODE HERE ###
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# Calculate total views for claim and opinion videos
total_views_claim = df[df['claim_status'] == 'claim']['video_view_count'].sum()
total_views_opinion = df[df['claim_status'] == 'opinion']['video_view_count'].sum()

# Pie chart data
labels = ['Claim Videos', 'Opinion Videos']
sizes = [total_views_claim, total_views_opinion]
colors = ['#ff9999','#66b3ff']

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Proportions of Total Views for Claim and Opinion Videos')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
"""
In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the median value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.

Write a for loop that iterates over the column names of each count variable. For each iteration:

Calculate the IQR of the column
Calculate the median of the column
Calculate the outlier threshold (median + 1.5 * IQR)
Calculate the numer of videos with a count in that column that exceeds the outlier threshold
Print "Number of outliers, {column name}: {outlier count}"
Example:
Number of outliers, video_view_count: ___
Number of outliers, video_like_count: ___
Number of outliers, video_share_count: ___
Number of outliers, video_download_count: ___
Number of outliers, video_comment_count: ___
"""
### YOUR CODE HERE ###

import pandas as pd

# Assuming 'data' is your DataFrame and it has been loaded correctly
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'

# List of count variables
count_columns = ['video_view_count', 'video_like_count', 'video_share_count',
                 'video_download_count', 'video_comment_count']

# Loop through each count variable
for column in count_columns:
    # Calculate IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Calculate median
    median = df[column].median()
    
    # Calculate outlier threshold
    outlier_threshold = median + 1.5 * IQR
    
    # Count number of outliers
    outlier_count = (df[column] > outlier_threshold).sum()
    
    # Print results
    print(f"Number of outliers, {column}: {outlier_count}")
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
### YOUR CODE HERE ###

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset into a DataFrame
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'
data = pd.read_csv(file_path)

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='video_view_count', y='video_like_count', hue='claim_status', data=data)
plt.title('Scatter Plot of Video View Count vs. Video Like Count by Claim Status')
plt.xlabel('Video View Count')
plt.ylabel('Video Like Count')
plt.legend(title='Claim Status')
plt.show()

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
### YOUR CODE HERE ###

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset into a DataFrame
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'
df = pd.read_csv(file_path)

# Filter data for videos categorized as opinions
opinion_videos = df[df['claim_status'] == 'opinion']

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='video_view_count', y='video_like_count', data=opinion_videos)
plt.title('Scatter Plot of Video View Count vs. Video Like Count for Opinions')
plt.xlabel('Video View Count')
plt.ylabel('Video Like Count')
plt.show()

# %%
# Plotting a histogram to know the shape of the data and batter understading of the data.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load the dataset
file_path = r'C:\Users\user\OneDrive\Desktop\Google Data Analytic Certification File\TikTok Project\tiktok_dataset.csv'
df = pd.read_csv(file_path)

# Drop rows with any missing values
df = df.dropna()

# Create histograms for all numerical columns
df.hist(figsize=(15, 10), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

df['Z_SCORE'] = stats.zscore(df['OVERALL_LI'])df
